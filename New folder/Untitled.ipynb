# %%
import pandas as pd

# %%
json = pd.read_json('https://margincalculator.angelbroking.com/OpenAPI_File/files/OpenAPIScripMaster.json')

# %%
json
# Out:
#          token             symbol        name     expiry     strike  lotsize  \
# 0        10412      KSHITIJPOL-BE  KSHITIJPOL                    -1        1
# 1         8684         729RJ32-SG     729RJ32                    -1      100
# 2        23546          75UK29-SG      75UK29                    -1      100
# 3         4380      SENSEXIETF-BL  SENSEXIETF                    -1        1
# 4         9360       1040UCL25-N4   1040UCL25                    -1        1
# ...        ...                ...         ...        ...        ...      ...
# 115493  126089  GOLDM24AUG68500CE       GOLDM  29AUG2024  685000000        1
# 115494  125831   GOLD25MAR72200PE        GOLD  28MAR2025  722000000        1
# 115495  126044  GOLDM24OCT67500CE       GOLDM  29OCT2024  675000000        1
# 115496  126367  GOLDM24SEP68700CE       GOLDM  26SEP2024  687000000        1
# 115497  126911   GOLD25MAR79100CE        GOLD  28MAR2025  791000000        1
#
#        instrumenttype exch_seg  tick_size
# ...

# %%
json.head(10)
# Out:
#    token         symbol        name expiry  strike  lotsize instrumenttype  \
# 0  10412  KSHITIJPOL-BE  KSHITIJPOL             -1        1
# 1   8684     729RJ32-SG     729RJ32             -1      100
# 2  23546      75UK29-SG      75UK29             -1      100
# 3   4380  SENSEXIETF-BL  SENSEXIETF             -1        1
# 4   9360   1040UCL25-N4   1040UCL25             -1        1
# 5  24056     738HR34-SG     738HR34             -1      100
# 6  15178        TRIL-BE        TRIL             -1        1
# 7   5497    SFMP49DD-MF    SFMP49DD             -1        1
# 8  20655    898LTF29-N7    898LTF29             -1        1
# 9  12065  CYBERMEDIA-BL  CYBERMEDIA             -1        1
#
#   exch_seg  tick_size
# 0      NSE          1
# 1      NSE          1
# 2      NSE          1
# 3      NSE          1
# 4      NSE          1
# 5      NSE          1
# 6      NSE          5
# 7      NSE          1
# 8      NSE          1
# 9      NSE          1

# %%
json.head(50)
# Out:
#     token         symbol        name expiry  strike  lotsize instrumenttype  \
# 0   10412  KSHITIJPOL-BE  KSHITIJPOL             -1        1
# 1    8684     729RJ32-SG     729RJ32             -1      100
# 2   23546      75UK29-SG      75UK29             -1      100
# 3    4380  SENSEXIETF-BL  SENSEXIETF             -1        1
# 4    9360   1040UCL25-N4   1040UCL25             -1        1
# 5   24056     738HR34-SG     738HR34             -1      100
# 6   15178        TRIL-BE        TRIL             -1        1
# 7    5497    SFMP49DD-MF    SFMP49DD             -1        1
# 8   20655    898LTF29-N7    898LTF29             -1        1
# 9   12065  CYBERMEDIA-BL  CYBERMEDIA             -1        1
# 10  10336     797AP39-SG     797AP39             -1      100
# 11   2988     SANDESH-EQ     SANDESH             -1        1
# 12   2236     702HP36-SG     702HP36             -1      100
# 13   1896     661RJ31-SG     661RJ31             -1      100
# ...

# %%
json.tail(50)
# Out:
#          token                symbol        name     expiry      strike  \
# 115448  127234    SILVER24SEP98000PE      SILVER  02SEP2024   980000000
# 115449  126984      ZINC24MAY257.5PE        ZINC  22MAY2024     2575000
# 115450  126895      GOLD25JAN78100CE        GOLD  29JAN2025   781000000
# 115451  127742  SILVERM25APR103750PE     SILVERM  23APR2025  1037500000
# 115452  126153      GOLD25JAN76300PE        GOLD  29JAN2025   763000000
# 115453  125849   SILVERM24NOV84000PE     SILVERM  22NOV2024   840000000
# 115454  126537  NATURALGAS24OCT165PE  NATURALGAS  24OCT2024     1650000
# 115455  127181      GOLD25JAN78700PE        GOLD  29JAN2025   787000000
# 115456  125687      GOLD25JAN71700PE        GOLD  29JAN2025   717000000
# 115457  126881      GOLD24NOV77200CE        GOLD  28NOV2024   772000000
# 115458  125827      GOLD24NOV72400PE        GOLD  28NOV2024   724000000
# 115459  125905      GOLD25MAY72400CE        GOLD  29MAY2025   724000000
# ...

# %%
json [['token', 'symbol','name']]
# Out:
#          token             symbol        name
# 0        10412      KSHITIJPOL-BE  KSHITIJPOL
# 1         8684         729RJ32-SG     729RJ32
# 2        23546          75UK29-SG      75UK29
# 3         4380      SENSEXIETF-BL  SENSEXIETF
# 4         9360       1040UCL25-N4   1040UCL25
# ...        ...                ...         ...
# 115493  126089  GOLDM24AUG68500CE       GOLDM
# 115494  125831   GOLD25MAR72200PE        GOLD
# 115495  126044  GOLDM24OCT67500CE       GOLDM
# 115496  126367  GOLDM24SEP68700CE       GOLDM
# 115497  126911   GOLD25MAR79100CE        GOLD
#
# [115498 rows x 3 columns]
